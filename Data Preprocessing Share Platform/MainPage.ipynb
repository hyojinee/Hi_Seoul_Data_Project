# %%
import tkinter as tk 
import mysql.connector  
from tkinter import * 
import PIL 
import tkinter.ttk
from PIL import ImageTk,Image
import googlemaps
import folium
import base64
import webbrowser
gmaps_key = 'AIzaSyD4g0TGz6sETw4a8ezqG-Rymy6UrZUa950'
gmaps = googlemaps.Client(key=gmaps_key)
gmaps.geocode('대한민국 서울특별시 강서구 등촌동', language='ko')

#mysql 사용자이름, 비밀번호
def submitact():  
    username = 'root'
    passw = 'hhyyoo'
    
    # Mysql연결 비밀번호 있음
    if passw:
        db = mysql.connector.connect(host ="localhost", 
                                     user = "root", 
                                     password = "hhyyoo", 
                                     db ="user1")
        global cursor
        cursor = db.cursor() 
          
    # 데이터베이스 비밀번호 없을시
    # user 
    else: 
        db = mysql.connector.connect(host ="localhost", 
                                     user = "root", 
                                     db ="user1") 
        cursor = db.cursor() 
          
    # 테이블 저장 
    savequery = "select * from login"
      
    try: 
        cursor.execute(savequery) 
        #저장테이블 확인
        myresult = cursor.fetchall() 
        #print(myresult)
        # 결과 
        for x in myresult: 
            print(x) 
        print("Query Excecuted successfully") 
          
    except: 
        db.rollback() 
        print("Error occured") 
        
    global userid
    global name
    userid = entry1.get() 
    passwd = entry2.get()
    print(f"The name entered by you is {userid} {passwd}")  
    #아이디 확인
    cursor.execute("select * from login where ID = '%s' " % (userid))
    exist = cursor.fetchall()
    name = exist[0][2]
    print(name)
    # print(exist)
    # print(passwd)
    
    # 비밀번호 확인
    if exist[0][2] == passwd:
        print(f"Welcome {exist[0][1]}")

    else:
        print('Error')
        
    cursor.close()
    db.close()
    combineNewwindow1()

def close():
    root.destroy()
    
def printlog():
    global log
    log = name +"님이 파일을 추가하였습니다."
    listbox.insert(1,log)
    #listbox.pack()
    listbox.place(x=70, y=250)
    
def combineNewwindow1():
    combineWindow = Toplevel()
    #tk.Tk()
    combineWindow.geometry("500x500")
    combineWindow.configure(bg="white")
    
# def open():
#     global my_img
#     combineWindow  = Toplevel()
#     my_img = ImageTk.PhotoImage(Image.open("navysmall2.gif"))
#     my_label = tkLabel(combineWindow , image=my_img).pack()
#     btn2 = Button(top, text="close", command=top.destroy).pack()
    
# btn = Button(root, text="open", command=open).pack()

   
    global my_img 
    my_img = ImageTk.PhotoImage(Image.open("navysmall2.gif"))
    my_label = tk.Label(combineWindow, image=my_img,width=80, height=80).place(x=40,y=10)
    
    labelExample = tk.Label(combineWindow, text = "My Page",fg="#0D1D3C",font=('family',17,'bold'))
    labelExample.configure(bg="white")
    
    labelE2 = tk.Label(combineWindow, text = name,fg="#0D1D3C",font=('family',13,'bold'))
    labelE2.configure(bg="white")    
    
    labelE3 = tk.Label(combineWindow, text = userid,fg="#0D1D3C",font=('family',10,'bold'))
    labelE3.configure(bg="white")   
    
    labelE4 = tk.Label(combineWindow, text="--------------------------------------------------------------------------------------------------------------------------",fg="#0D1D3C",font=('family',10,'bold'))
    labelE4.configure(bg="white")
    
    labelE5 = tk.Label(combineWindow, text ="클라우드공간",fg="#0D1D3C",font=('family',12,'bold'))
    labelE5.configure(bg="white")
    
    progressbar=tkinter.ttk.Progressbar(combineWindow,style='text.Horizontal.TProgressbar',length=200, maximum=10000,value=1400)
    progressbar.place(x=50,y=135)
    
    labelE6 = tk.Label(combineWindow, text ="--------------------------------------------------------------------------------------------------------------------------",fg="#0D1D3C",font=('family',10,'bold'))
    labelE6.configure(bg="white")
    
    labelE7 = tk.Label(combineWindow, text ="내 그룹",fg="#0D1D3C",font=('family',12,'bold'))
    labelE7.configure(bg="white")
    
    imagetest = PhotoImage(file="navysmall2.gif")

    buttonExample = tk.Button(combineWindow,image=imagetest,text = "그룹1",width=70, height=70,command = groupWindow, )
    buttonExample2 = tk.Button(combineWindow,text = "그룹2",command = combineWindow.destroy)
    buttonExample3 = tk.Button(combineWindow,text = "그룹3",command = combineWindow.destroy)
    buttonExample4 = tk.Button(combineWindow,text = "그룹4",command = combineWindow.destroy)
    
    labelE8 = tk.Label(combineWindow, text ="--------------------------------------------------------------------------------------------------------------------------",fg="#0D1D3C",font=('family',10,'bold'))
    labelE8.configure(bg="white")
    
    labelE9 = tk.Label(combineWindow, text ="데이터관리",fg="#0D1D3C",font=('family',18))
    labelE9.configure(bg="white")
    
    labelE10 = tk.Label(combineWindow, text ="--------------------------------------------------------------------------------------------------------------------------",fg="#0D1D3C",font=('family',10,'bold'))
    labelE10.configure(bg="white")
    
    labelE11 = tk.Label(combineWindow, text ="설정",fg="#0D1D3C",font=('family',18))
    labelE11.configure(bg="white")
    
    labelE12 = tk.Label(combineWindow, text ="--------------------------------------------------------------------------------------------------------------------------",fg="#0D1D3C",font=('family',10,'bold'))
    labelE12.configure(bg="white")
    
    labelE13 = tk.Label(combineWindow, text ="고객센터",fg="#0D1D3C",font=('family',18))
    labelE13.configure(bg="white")
    
    #위치좌표
    labelExample.place(x=200,y=10)
    labelE2.place(x=200,y=50)
    labelE3.place(x=200,y=70)
    labelE4.place(y=90)
    labelE5.place(x=10,y=110)
    labelE6.place(y=150)
    labelE7.place(x=10,y=170)
    labelE8.place(y=270)
    labelE9.place(x=10,y=300)
    labelE10.place(y=340)
    labelE11.place(x=10,y=375)
    labelE12.place(y=415)
    labelE13.place(x=10,y=445)
    buttonExample.place(x=20,y=195)
    buttonExample2.place(x=110,y=210)
    buttonExample3.place(x=170,y=210)
    buttonExample4.place(x=230,y=210)
     
    combineWindow.mainloop()
    
    #==================================================================================
    
def groupWindow():
    close()
    group = tk.Tk()
    group.geometry("500x500")
    group.configure(bg="white")
    
    notebook = tkinter.ttk.Notebook(group, width=500, height=500)
    # notebook.configure(bg="white")
    notebook.pack()

    # 탭생성
    frame1 = tkinter.Frame(group)
    frame1.configure(bg='white')
    notebook.add(frame1, text="실적관리")
    openmapbutton = tk.Button(frame1,text="Open Browser",bg='#F8AA00',font=('family bold',15),command = wbbrowser)
    openmapbutton.place(x=50,y=100)

    # 버튼생성
    imagetest2 = PhotoImage(file="down.gif")
    downloadbutton = tk.Button(frame1,image=imagetest2, font=('family bold',15),width=50, height=45,command = close)
    downloadbutton.place(x=40,y=400)
    
    imagetest3 = PhotoImage(file="up.gif")
    sharebutton = tk.Button(frame1,image=imagetest3,font=('family bold',15),width=50, height=45,command = printlog)
    sharebutton.place(x=200,y=400)
    
    closebutton = tk.Button(frame1,text = "  닫기   ",bg='#F8AA00',font=('family bold',15),command = group.destroy)
    closebutton.place(x=360,y=400)
 
    
    #탭 페이지
    label1 = tkinter.Label(frame1, bg="white", text = "실적관리",fg="#0D1D3C",font=('family',17,'bold'))
    label1.pack()
    global listbox
    listbox = Listbox(frame1,width=30, height=0, selectmode ="extended")
    listbox.insert(0,log)
    listbox.place(x=70, y=250)

#     loglabel = tkinter.Label(frame1, text = log)
#     loglabel.place(x=40, y=300)
    
    
    frame2 = tkinter.Frame(group)
    frame2.configure(bg='white')
    notebook.add(frame2, text="매출관리")

    label2 = tkinter.Label(frame2,bg="white", text="매출관리 내용")
    label2.pack()

    frame3 = tkinter.Frame(group)
    frame3.configure(bg='white')
    notebook.add(frame3, text="그룹멤버")

    label3 = tkinter.Label(frame3, bg="white",text="그룹멤버의 내용")
    label3.pack()

    notebook.enable_traversal()
    group.mainloop()

    
    
root = tk.Tk() 
root.geometry("500x500") 
root.title("Login Page") 
root.configure(bg='white')
#=============================================
#이미지 불러오기

img = PhotoImage(file = 'navysmall.gif')
label = Label(root, image = img, bg ='white',width=50, height=50)
label.place(x=10,y=-110,relwidth=1,relheight=1)
 
# Definging the first row   
entry1 = tk.Entry(root,bg="#0D1D3C",bd=True,fg='grey60',font=('family',17))
entry1.insert(0,"")
entry1.place(x=130,y=290,width=250,height=30)
   
entry2 = tk.Entry(root,bg="#0D1D3C",bd=True,fg='grey60',font=('family',17),show="*")
entry2.insert(0,"")
entry2.place(x=130,y=340,width=250,height=30)
  
submitbtn = tk.Button(root, text ="Login",  bg ="#F8AA00",fg ="white", command = submitact) 
submitbtn.place(x=210,y=400,width=80)

#Map

# Open html 
def wbbrowser():
    #기준 화면
    m = folium.Map(location=[37.5526346,126.8652954],zoom_start=17)
    #이미지 frame 크기
    pic1 = base64.b64encode(open('hyojin.jpg','rb').read()).decode()
    image_tag1 = '<img src="data:image/jpeg;base64,{}">'.format(pic1)
    iframe1 = folium.IFrame(image_tag1, width=170, height=170) 
    popup1 = folium.Popup(iframe1, max_width=650)

    pic2 = base64.b64encode(open('heart.png','rb').read()).decode()
    image_tag2 = '<img src="data:image/jpeg;base64,{}">'.format(pic2)
    iframe2 = folium.IFrame(image_tag2, width=170, height=170) 
    popup2 = folium.Popup(iframe2, max_width=650)


    folium.Marker([37.5526346,126.8652954],popup=popup1, tooltip='seo').add_to(m)
    folium.Marker([37.5526100,126.8640000],popup=popup2, tooltip='min').add_to(m)

    #맵 출력
    # m
    # create html map 
    m.save('map.html')
    
    webbrowser.open_new_tab('map.html')




root.mainloop()
